# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Normalizer
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 ds = pd.read_excel("/content/drive/MyDrive/combined_raman_spectra.xlsx")

 ds.head()
# Out:
#    Raman Shift  \
# 0      400.083
# 1      401.858
# 2      403.630
# 3      405.405
# 4      407.176
#
#    Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                            29323.0
# 1                                            29154.5
# 2                                            29128.7
# 3                                            29056.1
# 4                                            29063.2
#
#    Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                            20007.5
# 1                                            19914.4
# 2                                            19858.3
# 3                                            19871.0
# 4                                            19839.6
#
#    Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                            15214.7
# ...

# %%
x = ds["Raman Shift"]

ds_intensities = ds.drop("Raman Shift", axis=1)

ds_intensities = savgol_filter(ds_intensities, 5, 2)

ds_intensities = pd.DataFrame(ds_intensities , columns = ['Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul toned milk after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Amul toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt',
       'Heritage full cream RT 532nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt',
       'Heritage full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole after heating.txt',
       'Heritage full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt',
       'Heritage full cream RT 633nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt',
       'Heritage full cream RT 785nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt',
       'Heritage full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage special 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt',
       'Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole_Re.txt',
       'Heritage special RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage special acidic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage special basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage toned Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage toned RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage toned RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage toned after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Heritage toned basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani full cream RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt',
       'Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani toned milk RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nandani toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt',
       'Nestle toned milk Cold 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt',
       'Nestle toned milk RT 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt',
       'Nestle toned milk after heating 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt',
       'Nestle toned milk basic 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt'])

ds_intensities.head()
# Out:
#    Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                       28276.914286
# 1                                       28118.337143
# 2                                       28059.968571
# 3                                       28009.462857
# 4                                       28019.742857
#
#    Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                       20932.062857
# 1                                       20823.751429
# 2                                       20822.365714
# 3                                       20795.028571
# 4                                       20763.688571
#
#    Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                       18717.525714
# 1                                       18618.122857
# 2                                       18637.791429
# ...

# %%
from scipy import sparse
from scipy.sparse.linalg import spsolve


def baseline_als(y, lam=10e6, p=0.01, niter=10):
    L = len(y)
    D = sparse.diags([1, -2, 1], [0, -1, -2], shape=(L, L-2), format='csc')
    w = np.ones(L)
    for i in range(niter):
        W = sparse.spdiags(w, 0, L, L)
        Z = W + lam * D.dot(D.T)
        z = spsolve(Z, w * y)
        w = p * (y > z) + (1 - p) * (y < z)
    return z

z = ds_intensities.apply(lambda col: baseline_als(col.values, lam=1e6, p=0.01), axis=0)


ds_corrected = ds_intensities - z

ds_corrected.head()
# Out:
#    Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                         999.317107
# 1                                         849.564562
# 2                                         800.020579
# 3                                         758.339425
# 4                                         777.443930
#
#    Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                        1073.400953
# 1                                         971.072150
# 2                                         975.669050
# 3                                         954.314490
# 4                                         928.957012
#
#    Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                        1161.083306
# 1                                        1067.165289
# 2                                        1092.318690
# ...

# %%
df = pd.concat([x, ds_corrected], axis=1)

df.head()
# Out:
#    Raman Shift  \
# 0      400.083
# 1      401.858
# 2      403.630
# 3      405.405
# 4      407.176
#
#    Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                         999.317107
# 1                                         849.564562
# 2                                         800.020579
# 3                                         758.339425
# 4                                         777.443930
#
#    Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                        1073.400953
# 1                                         971.072150
# 2                                         975.669050
# 3                                         954.314490
# 4                                         928.957012
#
#    Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt  \
# 0                                        1161.083306
# ...

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x = "Raman Shift" , y = "Nandani toned milk RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , data = df )
plt.ylabel("Intensity")
plt.xlabel("Raman Shift")
plt.title("Raman Spectra")
plt.show()

# %%
df.to_excel("/content/drive/MyDrive/preprocessed_raman_spectra.xlsx")
