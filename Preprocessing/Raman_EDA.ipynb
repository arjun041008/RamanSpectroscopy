# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA

# %%
df = pd.read_excel("/content/drive/MyDrive/RSI_Google Colabs/preprocessed_raman_spectra.xlsx")

df.head(5)
# Out:
#    Unnamed: 0  ...  Nestle toned milk basic 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt
# 0           0  ...                                         119.087542
# 1           1  ...                                         -70.217388
# 2           2  ...                                         -37.722318
# 3           3  ...                                         -33.932896
# 4           4  ...                                         -30.680444
#
# [5 rows x 46 columns]

# %%
df_analysis = pd.DataFrame()
df_analysis["Raman Shift"] = df["Raman Shift"]

df_analysis["Avg. Toned"] = df[["Amul toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt" , "Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole_Re.txt" , "Heritage special RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special acidic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt" , "Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nestle toned milk Cold 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt" , "Nestle toned milk RT 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt" , "Nestle toned milk after heating 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt" , "Nestle toned milk after heating 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt"]].mean(axis = 1)
df_analysis["Avg. Full Cream"] = df[["Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt" , "Heritage full cream RT 532nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole after heating.txt" , "Heritage full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt" , "Heritage full cream RT 633nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT 785nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt"]].mean(axis = 1)
df_analysis.tail()
# Out:
#       Raman Shift  Avg. Toned  Avg. Full Cream
# 2113      3494.24  -57.502635       -56.043836
# 2114      3495.45  -60.835322       -62.975323
# 2115      3496.67  -69.979244       -74.690940
# 2116      3497.88  -93.324086       -94.848672
# 2117      3499.09 -103.199715       -93.078272

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
line1, = ax.plot(df_analysis["Raman Shift"], df_analysis["Avg. Toned"], label="Toned")
line2, = ax.plot(df_analysis["Raman Shift"], df_analysis["Avg. Full Cream"], label="Full Cream")
ax.set_ylabel("Intensity")
ax.set_xlabel("Raman Shift (cm⁻¹)")
ax.set_title("Average Raman Spectra of Toned and Full Cream Milk")

ax.legend()

plt.show()

# %%
df_analysis["Room"] = df[["Amul full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream RT 532nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt" , "Heritage full cream RT 633nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT 785nm 100% 600g 50xL 10s 10times 400-3500cm-1.txt" , "Heritage full cream RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole_Re.txt" , "Heritage special RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special acidic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt" , "Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT after 24 h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT after 24h 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nestle toned milk RT 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt" , "Nestle toned milk basic 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt"]].mean(axis = 1)
df_analysis["Cold"] = df[["Amul full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 100hole.txt" , "Heritage toned Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk Cold 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nestle toned milk Cold 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt"]].mean(axis = 1)
df_analysis["Hot"] = df[["Amul full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt" , "Heritage toned after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream after heating 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk RT 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole after heating.txt" , "Nestle toned milk after heating 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt"]].mean(axis = 1)

df_analysis.sample(10)
# Out:
#       Raman Shift   Avg. Toned  ...         Cold          Hot
# 1090      2141.78   369.497931  ...   340.620242   357.512748
# 773       1672.37   734.915161  ...   874.353252   814.877002
# 1126      2193.66   567.701535  ...   522.372173   514.893696
# 754       1643.31   862.223675  ...  1242.549793  1104.369561
# 1565      2800.09   -45.089774  ...   -90.281772   -62.048302
# 1679      2949.99  1398.960345  ...  2502.473785  1998.237370
# 1900      3232.23   771.104354  ...   918.999024   784.290460
# 1062      2101.18   182.979219  ...   170.985518   176.338794
# 1234      2347.31   246.054009  ...   244.528437   251.535977
# 1789      3091.82   113.285977  ...    99.788463    87.713728
#
# [10 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
line1, = ax.plot(df_analysis["Raman Shift"], df_analysis["Hot"], label="Heated Milk Sample")
line2, = ax.plot(df_analysis["Raman Shift"], df_analysis["Room"], label="Room Temperature Milk Sample")
line3, = ax.plot(df_analysis["Raman Shift"], df_analysis["Cold"], label="Cold Milk Sample")
ax.set_ylabel("Intensity")
ax.set_xlabel("Raman Shift (cm⁻¹)")
ax.set_title("Varaition of Raman Spectra with Temperature")

ax.legend()

plt.show()

# %%
df_analysis["Basic"] = df[["Amul full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nestle toned milk basic 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt"]].mean(axis = 1)
df_analysis["Regular"] = df.drop(columns=["Amul full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Amul toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage special basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Heritage toned basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani full cream basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nandani toned milk basic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt" , "Nestle toned milk basic 532nm 50% 600g 50xL 7s 20times 400-3500cm-1 200hole.txt" , "Heritage special acidic 532nm 50% 600g 50xL 10s 10times 400-3500cm-1 200hole.txt"]).mean(axis = 1)

df_analysis.head(5)
# Out:
#    Raman Shift  Avg. Toned  Avg. Full Cream  ...         Hot       Basic     Regular
# 0      400.083  231.950032       823.769449  ...  542.253123  549.647216  454.427015
# 1      401.858  108.648019       701.479998  ...  406.042617  419.394408  338.552993
# 2      403.630   75.928640       672.532555  ...  398.865982  381.933502  311.752196
# 3      405.405  113.991921       692.511096  ...  420.768554  409.059762  340.230616
# 4      407.176  134.629800       701.253068  ...  432.504271  416.330320  357.767875
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
line1, = ax.plot(df_analysis["Raman Shift"], df_analysis["Regular"], label="Regular")
line2, = ax.plot(df_analysis["Raman Shift"], df_analysis["Basic"], label="Basic")
ax.set_ylabel("Intensity")
ax.set_xlabel("Raman Shift (cm⁻¹)")
ax.set_title("Average Raman Spectra of Regular vs. Basic Milk")

ax.legend()

plt.show()

# %%
df.index = df["Raman Shift"]
df.drop(columns=["Raman Shift" , "Unnamed: 0"], inplace=True)

df_pca = df.transpose()
df_pca.head(5)
# Out:
# Raman Shift                                            400.083   ...    3499.090
# Amul full cream Cold 532nm 50% 600g 50xL 10s 10...   999.317107  ... -145.133653
# Amul full cream RT 532nm 50% 600g 50xL 10s 10ti...  1073.400953  ...  -89.159556
# Amul full cream RT after 24h 532nm 50% 600g 50x...  1161.083306  ...  -71.117011
# Amul full cream after heating 532nm 50% 600g 50...  1720.117063  ... -105.363094
# Amul full cream basic 532nm 50% 600g 50xL 10s 1...  1191.077263  ... -127.800026
#
# [5 rows x 2118 columns]

# %%
pd.DataFrame(Normalizer().fit_transform(df_pca), columns = df_pca.columns, index = df_pca.index)
# Out:
# Raman Shift                                         400.083   ...  3499.090
# Amul full cream Cold 532nm 50% 600g 50xL 10s 10...  0.011015  ... -0.001600
# Amul full cream RT 532nm 50% 600g 50xL 10s 10ti...  0.010712  ... -0.000890
# Amul full cream RT after 24h 532nm 50% 600g 50x...  0.011161  ... -0.000684
# Amul full cream after heating 532nm 50% 600g 50...  0.014345  ... -0.000879
# Amul full cream basic 532nm 50% 600g 50xL 10s 1...  0.012601  ... -0.001352
# Amul toned milk Cold 532nm 50% 600g 50xL 10s 10...  0.004063  ... -0.003355
# Amul toned milk RT 532nm 50% 600g 50xL 10s 10ti...  0.003384  ... -0.002416
# Amul toned milk RT after 24h 532nm 50% 600g 50x...  0.003603  ... -0.002393
# Amul toned milk after heating 532nm 50% 600g 50...  0.004435  ... -0.003204
# Amul toned milk basic 532nm 50% 600g 50xL 10s 1...  0.004367  ... -0.003859
# Heritage full cream Cold 532nm 50% 600g 50xL 10...  0.004510  ... -0.001985
# ...

# %%
pca = PCA(n_components = 3)

df_pca_analysis = pd.DataFrame(pca.fit_transform(df_pca) , columns = ["PC1" , "PC2" , "PC3"] , index = df_pca.index)

# %%
ser1 = pd.Series([['Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Full Cream', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned', 'Toned']])

df_pca_analysis["Milk Type"] = ser1.values[0]

df_pca_analysis.head(5)
# Out:
#                                                              PC1  ...   Milk Type
# Amul full cream Cold 532nm 50% 600g 50xL 10s 10...  39317.668602  ...  Full Cream
# Amul full cream RT 532nm 50% 600g 50xL 10s 10ti...  49717.806076  ...  Full Cream
# Amul full cream RT after 24h 532nm 50% 600g 50x...  53645.298885  ...  Full Cream
# Amul full cream after heating 532nm 50% 600g 50...  68350.020519  ...  Full Cream
# Amul full cream basic 532nm 50% 600g 50xL 10s 1...  42673.368614  ...  Full Cream
#
# [5 rows x 4 columns]

# %%
fig = px.scatter_3d(df_pca_analysis, x='PC1', y='PC2', z='PC3',
                    color='Milk Type',
                    title='PCA Analysis of Milk Type')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
